# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from core.plotting import set_plotting_defaults
from definitions import paper_fig_dir
import os
import os.path as op
from adaptation.adaptation_generalization_test import make_generalization_plot
from core.continuous_env import ReachTask
from core.agent import ACLearningAgentWithEmbedding
from core.config import config as pre_cfg
from adaptation.config import config as post_cfg
from tqdm.notebook import tqdm
from definitions import paper_model_path, paper_fig_dir
import distinctipy
import torch
import random

# %%
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.colors import ListedColormap
# plt.rcParams['text.usetex'] = True

critic_loss_color = '#A94850'
angle_diff_color = '#44123F'
embedding_loss_color = '#6067B6'


n_acts = 24

colors = distinctipy.get_colors(n_acts, pastel_factor=0.7)
cmap = ListedColormap(colors)

# %%
# fix random seed (we'll load in a model and sample actions from the policy)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
os.listdir(paper_fig_dir)
# Out:
# ['.gitkeep',
#  'embedding_loss.pdf',
#  'embeddings_ep_0_target_0_seed_0.png',
#  'action_hist_episode_0_target_0_seed_0.npy',
#  'action_hist_0_target_0_seed_0.pdf',
#  'embeddings_ep_10000_target_0_seed_0.png',
#  'action_hist_episode_10000_target_0_seed_0.npy',
#  'embeddings_ep_20000_target_0_seed_0.png',
#  'action_hist_episode_20000_target_0_seed_0.npy',
#  'embeddings_ep_30000_target_0_seed_0.png',
#  'action_hist_episode_30000_target_0_seed_0.npy',
#  'embeddings_ep_40000_target_0_seed_0.png',
#  'action_hist_episode_40000_target_0_seed_0.npy',
#  'embeddings_ep_50000_target_0_seed_0.png',
#  'action_hist_episode_50000_target_0_seed_0.npy',
#  'embeddings_ep_60000_target_0_seed_0.png',
#  'action_hist_episode_60000_target_0_seed_0.npy',
#  'embeddings_ep_70000_target_0_seed_0.png',
#  'action_hist_episode_70000_target_0_seed_0.npy',
#  'embeddings_ep_80000_target_0_seed_0.png',
#  'action_hist_episode_80000_target_0_seed_0.npy',
#  'embeddings_ep_90000_target_0_seed_0.png',
#  'action_hist_episode_90000_target_0_seed_0.npy',
#  'embeddings_ep_100000_target_0_seed_0.png',
#  'action_hist_episode_100000_target_0_seed_0.npy',
#  'embeddings_ep_110000_target_0_seed_0.png',
#  'action_hist_episode_110000_target_0_seed_0.npy',
#  'embeddings_ep_120000_target_0_seed_0.png',
#  'action_hist_episode_120000_target_0_seed_0.npy',
#  'embeddings_ep_130000_target_0_seed_0.png',
#  'action_hist_episode_130000_target_0_seed_0.npy',
#  'embeddings_ep_140000_target_0_seed_0.png',
#  'action_hist_episode_140000_target_0_seed_0.npy',
#  'embeddings_ep_150000_target_0_seed_0.png',
#  'action_hist_episode_150000_target_0_seed_0.npy',
#  'embeddings_ep_160000_target_0_seed_0.png',
#  'action_hist_episode_160000_target_0_seed_0.npy',
#  'embeddings_ep_170000_target_0_seed_0.png',
#  'action_hist_episode_170000_target_0_seed_0.npy',
#  'embeddings_ep_180000_target_0_seed_0.png',
#  'action_hist_episode_180000_target_0_seed_0.npy',
#  'embeddings_ep_190000_target_0_seed_0.png',
#  'action_hist_episode_190000_target_0_seed_0.npy',
#  'critic_loss_target_0_seed_0.npy',
#  'loss_target_0_seed_0.pdf',
#  'angle_differences_target_0_seed_0.npy',
#  'angular_error_target_0_seed_0.pdf',
#  'embeddings_ep_0_target_15_seed_0.png',
#  'action_hist_episode_0_target_15_seed_0.npy',
#  'action_hist_0_target_15_seed_0.pdf',
#  'embeddings_ep_10000_target_15_seed_0.png',
#  'action_hist_episode_10000_target_15_seed_0.npy',
#  'embeddings_ep_20000_target_15_seed_0.png',
#  'action_hist_episode_20000_target_15_seed_0.npy',
#  'embeddings_ep_30000_target_15_seed_0.png',
#  'action_hist_episode_30000_target_15_seed_0.npy',
#  'embeddings_ep_40000_target_15_seed_0.png',
#  'action_hist_episode_40000_target_15_seed_0.npy',
#  'embeddings_ep_50000_target_15_seed_0.png',
#  'action_hist_episode_50000_target_15_seed_0.npy',
#  'embeddings_ep_60000_target_15_seed_0.png',
#  'action_hist_episode_60000_target_15_seed_0.npy',
#  'embeddings_ep_70000_target_15_seed_0.png',
#  'action_hist_episode_70000_target_15_seed_0.npy',
#  'embeddings_ep_80000_target_15_seed_0.png',
#  'action_hist_episode_80000_target_15_seed_0.npy',
#  'embeddings_ep_90000_target_15_seed_0.png',
#  'action_hist_episode_90000_target_15_seed_0.npy',
#  'embeddings_ep_100000_target_15_seed_0.png',
#  'action_hist_episode_100000_target_15_seed_0.npy',
#  'embeddings_ep_110000_target_15_seed_0.png',
#  'action_hist_episode_110000_target_15_seed_0.npy',
#  'embeddings_ep_120000_target_15_seed_0.png',
#  'action_hist_episode_120000_target_15_seed_0.npy',
#  'embeddings_ep_130000_target_15_seed_0.png',
#  'action_hist_episode_130000_target_15_seed_0.npy',
#  'embeddings_ep_140000_target_15_seed_0.png',
#  'action_hist_episode_140000_target_15_seed_0.npy',
#  'embeddings_ep_150000_target_15_seed_0.png',
#  'action_hist_episode_150000_target_15_seed_0.npy',
#  'embeddings_ep_160000_target_15_seed_0.png',
#  'action_hist_episode_160000_target_15_seed_0.npy',
#  'embeddings_ep_170000_target_15_seed_0.png',
#  'action_hist_episode_170000_target_15_seed_0.npy',
#  'embeddings_ep_180000_target_15_seed_0.png',
#  'action_hist_episode_180000_target_15_seed_0.npy',
#  'embeddings_ep_190000_target_15_seed_0.png',
#  'action_hist_episode_190000_target_15_seed_0.npy',
#  'critic_loss_target_15_seed_0.npy',
#  'loss_target_15_seed_0.pdf',
#  'angle_differences_target_15_seed_0.npy',
#  'angular_error_target_15_seed_0.pdf',
#  'embeddings_ep_0_target_30_seed_0.png',
#  'action_hist_episode_0_target_30_seed_0.npy',
#  'action_hist_0_target_30_seed_0.pdf',
#  'embeddings_ep_10000_target_30_seed_0.png',
#  'action_hist_episode_10000_target_30_seed_0.npy',
#  'embeddings_ep_20000_target_30_seed_0.png',
#  'action_hist_episode_20000_target_30_seed_0.npy',
#  'embeddings_ep_30000_target_30_seed_0.png',
#  'action_hist_episode_30000_target_30_seed_0.npy',
#  'embeddings_ep_40000_target_30_seed_0.png',
#  'action_hist_episode_40000_target_30_seed_0.npy',
#  'embeddings_ep_50000_target_30_seed_0.png',
#  'action_hist_episode_50000_target_30_seed_0.npy',
#  'embeddings_ep_60000_target_30_seed_0.png',
#  'action_hist_episode_60000_target_30_seed_0.npy',
#  'embeddings_ep_70000_target_30_seed_0.png',
#  'action_hist_episode_70000_target_30_seed_0.npy',
#  'embeddings_ep_80000_target_30_seed_0.png',
#  'action_hist_episode_80000_target_30_seed_0.npy',
#  'embeddings_ep_90000_target_30_seed_0.png',
#  'action_hist_episode_90000_target_30_seed_0.npy',
#  'embeddings_ep_100000_target_30_seed_0.png',
#  'action_hist_episode_100000_target_30_seed_0.npy',
#  'embeddings_ep_110000_target_30_seed_0.png',
#  'action_hist_episode_110000_target_30_seed_0.npy',
#  'embeddings_ep_120000_target_30_seed_0.png',
#  'action_hist_episode_120000_target_30_seed_0.npy',
#  'embeddings_ep_130000_target_30_seed_0.png',
#  'action_hist_episode_130000_target_30_seed_0.npy',
#  'embeddings_ep_140000_target_30_seed_0.png',
#  'action_hist_episode_140000_target_30_seed_0.npy',
#  'embeddings_ep_150000_target_30_seed_0.png',
#  'action_hist_episode_150000_target_30_seed_0.npy',
#  'embeddings_ep_160000_target_30_seed_0.png',
#  'action_hist_episode_160000_target_30_seed_0.npy',
#  'embeddings_ep_170000_target_30_seed_0.png',
#  'action_hist_episode_170000_target_30_seed_0.npy',
#  'embeddings_ep_180000_target_30_seed_0.png',
#  'action_hist_episode_180000_target_30_seed_0.npy',
#  'embeddings_ep_190000_target_30_seed_0.png',
#  'action_hist_episode_190000_target_30_seed_0.npy',
#  'critic_loss_target_30_seed_0.npy',
#  'loss_target_30_seed_0.pdf',
#  'angle_differences_target_30_seed_0.npy',
#  'angular_error_target_30_seed_0.pdf',
#  'embeddings_ep_0_target_45_seed_0.png',
#  'action_hist_episode_0_target_45_seed_0.npy',
#  'action_hist_0_target_45_seed_0.pdf',
#  'embeddings_ep_10000_target_45_seed_0.png',
#  'action_hist_episode_10000_target_45_seed_0.npy',
#  'embeddings_ep_20000_target_45_seed_0.png',
#  'action_hist_episode_20000_target_45_seed_0.npy',
#  'embeddings_ep_30000_target_45_seed_0.png',
#  'action_hist_episode_30000_target_45_seed_0.npy',
#  'embeddings_ep_40000_target_45_seed_0.png',
#  'action_hist_episode_40000_target_45_seed_0.npy',
#  'embeddings_ep_50000_target_45_seed_0.png',
#  'action_hist_episode_50000_target_45_seed_0.npy',
#  'embeddings_ep_60000_target_45_seed_0.png',
#  'action_hist_episode_60000_target_45_seed_0.npy',
#  'embeddings_ep_70000_target_45_seed_0.png',
#  'action_hist_episode_70000_target_45_seed_0.npy',
#  'embeddings_ep_80000_target_45_seed_0.png',
#  'action_hist_episode_80000_target_45_seed_0.npy',
#  'embeddings_ep_90000_target_45_seed_0.png',
#  'action_hist_episode_90000_target_45_seed_0.npy',
#  'embeddings_ep_100000_target_45_seed_0.png',
#  'action_hist_episode_100000_target_45_seed_0.npy',
#  'embeddings_ep_110000_target_45_seed_0.png',
#  'action_hist_episode_110000_target_45_seed_0.npy',
#  'embeddings_ep_120000_target_45_seed_0.png',
#  'action_hist_episode_120000_target_45_seed_0.npy',
#  'embeddings_ep_130000_target_45_seed_0.png',
#  'action_hist_episode_130000_target_45_seed_0.npy',
#  'embeddings_ep_140000_target_45_seed_0.png',
#  'action_hist_episode_140000_target_45_seed_0.npy',
#  'embeddings_ep_150000_target_45_seed_0.png',
#  'action_hist_episode_150000_target_45_seed_0.npy',
#  'embeddings_ep_160000_target_45_seed_0.png',
#  'action_hist_episode_160000_target_45_seed_0.npy',
#  'embeddings_ep_170000_target_45_seed_0.png',
#  'action_hist_episode_170000_target_45_seed_0.npy',
#  'embeddings_ep_180000_target_45_seed_0.png',
#  'action_hist_episode_180000_target_45_seed_0.npy',
#  'embeddings_ep_190000_target_45_seed_0.png',
#  'action_hist_episode_190000_target_45_seed_0.npy',
#  'critic_loss_target_45_seed_0.npy',
#  'loss_target_45_seed_0.pdf',
#  'angle_differences_target_45_seed_0.npy',
#  'angular_error_target_45_seed_0.pdf',
#  'embeddings_ep_0_target_60_seed_0.png',
#  'action_hist_episode_0_target_60_seed_0.npy',
#  'action_hist_0_target_60_seed_0.pdf',
#  'embeddings_ep_10000_target_60_seed_0.png',
#  'action_hist_episode_10000_target_60_seed_0.npy',
#  'embeddings_ep_20000_target_60_seed_0.png',
#  'action_hist_episode_20000_target_60_seed_0.npy',
#  'embeddings_ep_30000_target_60_seed_0.png',
#  'action_hist_episode_30000_target_60_seed_0.npy',
#  'embeddings_ep_40000_target_60_seed_0.png',
#  'action_hist_episode_40000_target_60_seed_0.npy',
#  'embeddings_ep_50000_target_60_seed_0.png',
#  'action_hist_episode_50000_target_60_seed_0.npy',
#  'embeddings_ep_60000_target_60_seed_0.png',
#  'action_hist_episode_60000_target_60_seed_0.npy',
#  'embeddings_ep_70000_target_60_seed_0.png',
#  'action_hist_episode_70000_target_60_seed_0.npy',
#  'embeddings_ep_80000_target_60_seed_0.png',
#  'action_hist_episode_80000_target_60_seed_0.npy',
#  'embeddings_ep_90000_target_60_seed_0.png',
#  'action_hist_episode_90000_target_60_seed_0.npy',
#  'embeddings_ep_100000_target_60_seed_0.png',
#  'action_hist_episode_100000_target_60_seed_0.npy',
#  'embeddings_ep_110000_target_60_seed_0.png',
#  'critic_loss_target_60_seed_0.npy',
#  'action_hist_episode_110000_target_60_seed_0.npy',
#  'embeddings_ep_120000_target_60_seed_0.png',
#  'action_hist_episode_120000_target_60_seed_0.npy',
#  'embeddings_ep_130000_target_60_seed_0.png',
#  'action_hist_episode_130000_target_60_seed_0.npy',
#  'embeddings_ep_140000_target_60_seed_0.png',
#  'action_hist_episode_140000_target_60_seed_0.npy',
#  'embeddings_ep_150000_target_60_seed_0.png',
#  'action_hist_episode_150000_target_60_seed_0.npy',
#  'embeddings_ep_160000_target_60_seed_0.png',
#  'action_hist_episode_160000_target_60_seed_0.npy',
#  'embeddings_ep_170000_target_60_seed_0.png',
#  'action_hist_episode_170000_target_60_seed_0.npy',
#  'embeddings_ep_180000_target_60_seed_0.png',
#  'action_hist_episode_180000_target_60_seed_0.npy',
#  'embeddings_ep_190000_target_60_seed_0.png',
#  'action_hist_episode_190000_target_60_seed_0.npy',
#  'loss_target_60_seed_0.pdf',
#  'angle_differences_target_60_seed_0.npy',
#  'angular_error_target_60_seed_0.pdf',
#  'embeddings_ep_0_target_75_seed_0.png',
#  'action_hist_episode_0_target_75_seed_0.npy',
#  'action_hist_0_target_75_seed_0.pdf',
#  'embeddings_ep_10000_target_75_seed_0.png',
#  'action_hist_episode_10000_target_75_seed_0.npy',
#  'embeddings_ep_20000_target_75_seed_0.png',
#  'action_hist_episode_20000_target_75_seed_0.npy',
#  'embeddings_ep_30000_target_75_seed_0.png',
#  'action_hist_episode_30000_target_75_seed_0.npy',
#  'embeddings_ep_40000_target_75_seed_0.png',
#  'action_hist_episode_40000_target_75_seed_0.npy',
#  'embeddings_ep_50000_target_75_seed_0.png',
#  'action_hist_episode_50000_target_75_seed_0.npy',
#  'embeddings_ep_60000_target_75_seed_0.png',
#  'action_hist_episode_60000_target_75_seed_0.npy',
#  'embeddings_ep_70000_target_75_seed_0.png',
#  'action_hist_episode_70000_target_75_seed_0.npy',
#  'embeddings_ep_80000_target_75_seed_0.png',
#  'action_hist_episode_80000_target_75_seed_0.npy',
#  'embeddings_ep_90000_target_75_seed_0.png',
#  'action_hist_episode_90000_target_75_seed_0.npy',
#  'embeddings_ep_100000_target_75_seed_0.png',
#  'action_hist_episode_100000_target_75_seed_0.npy',
#  'embeddings_ep_110000_target_75_seed_0.png',
#  'action_hist_episode_110000_target_75_seed_0.npy',
#  'embeddings_ep_120000_target_75_seed_0.png',
#  'action_hist_episode_120000_target_75_seed_0.npy',
#  'embeddings_ep_130000_target_75_seed_0.png',
#  'action_hist_episode_130000_target_75_seed_0.npy',
#  'embeddings_ep_140000_target_75_seed_0.png',
#  'action_hist_episode_140000_target_75_seed_0.npy',
#  'embeddings_ep_150000_target_75_seed_0.png',
#  'action_hist_episode_150000_target_75_seed_0.npy',
#  'embeddings_ep_160000_target_75_seed_0.png',
#  'action_hist_episode_160000_target_75_seed_0.npy',
#  'embeddings_ep_170000_target_75_seed_0.png',
#  'action_hist_episode_170000_target_75_seed_0.npy',
#  'embeddings_ep_180000_target_75_seed_0.png',
#  'action_hist_episode_180000_target_75_seed_0.npy',
#  'embeddings_ep_190000_target_75_seed_0.png',
#  'action_hist_episode_190000_target_75_seed_0.npy',
#  'critic_loss_target_75_seed_0.npy',
#  'loss_target_75_seed_0.pdf',
#  'angle_differences_target_75_seed_0.npy',
#  'angular_error_target_75_seed_0.pdf',
#  'embeddings_ep_0_target_90_seed_0.png',
#  'action_hist_episode_0_target_90_seed_0.npy',
#  'action_hist_0_target_90_seed_0.pdf',
#  'embeddings_ep_10000_target_90_seed_0.png',
#  'action_hist_episode_10000_target_90_seed_0.npy',
#  'embeddings_ep_20000_target_90_seed_0.png',
#  'action_hist_episode_20000_target_90_seed_0.npy',
#  'embeddings_ep_30000_target_90_seed_0.png',
#  'action_hist_episode_30000_target_90_seed_0.npy',
#  'embeddings_ep_40000_target_90_seed_0.png',
#  'action_hist_episode_40000_target_90_seed_0.npy',
#  'embeddings_ep_50000_target_90_seed_0.png',
#  'action_hist_episode_50000_target_90_seed_0.npy',
#  'embeddings_ep_60000_target_90_seed_0.png',
#  'action_hist_episode_60000_target_90_seed_0.npy',
#  'embeddings_ep_70000_target_90_seed_0.png',
#  'action_hist_episode_70000_target_90_seed_0.npy',
#  'embeddings_ep_80000_target_90_seed_0.png',
#  'action_hist_episode_80000_target_90_seed_0.npy',
#  'embeddings_ep_90000_target_90_seed_0.png',
#  'action_hist_episode_90000_target_90_seed_0.npy',
#  'embeddings_ep_100000_target_90_seed_0.png',
#  'action_hist_episode_100000_target_90_seed_0.npy',
#  'embeddings_ep_110000_target_90_seed_0.png',
#  'action_hist_episode_110000_target_90_seed_0.npy',
#  'embeddings_ep_120000_target_90_seed_0.png',
#  'action_hist_episode_120000_target_90_seed_0.npy',
#  'embeddings_ep_130000_target_90_seed_0.png',
#  'action_hist_episode_130000_target_90_seed_0.npy',
#  'embeddings_ep_140000_target_90_seed_0.png',
#  'action_hist_episode_140000_target_90_seed_0.npy',
#  'embeddings_ep_150000_target_90_seed_0.png',
#  'action_hist_episode_150000_target_90_seed_0.npy',
#  'embeddings_ep_160000_target_90_seed_0.png',
#  'action_hist_episode_160000_target_90_seed_0.npy',
#  'embeddings_ep_170000_target_90_seed_0.png',
#  'action_hist_episode_170000_target_90_seed_0.npy',
#  'embeddings_ep_180000_target_90_seed_0.png',
#  'action_hist_episode_180000_target_90_seed_0.npy',
#  'embeddings_ep_190000_target_90_seed_0.png',
#  'action_hist_episode_190000_target_90_seed_0.npy',
#  'critic_loss_target_90_seed_0.npy',
#  'loss_target_90_seed_0.pdf',
#  'angle_differences_target_90_seed_0.npy',
#  'angular_error_target_90_seed_0.pdf',
#  'embeddings_ep_0_target_105_seed_0.png',
#  'action_hist_episode_0_target_105_seed_0.npy',
#  'action_hist_0_target_105_seed_0.pdf',
#  'embeddings_ep_10000_target_105_seed_0.png',
#  'action_hist_episode_10000_target_105_seed_0.npy',
#  'embeddings_ep_20000_target_105_seed_0.png',
#  'action_hist_episode_20000_target_105_seed_0.npy',
#  'embeddings_ep_30000_target_105_seed_0.png',
#  'action_hist_episode_30000_target_105_seed_0.npy',
#  'embeddings_ep_40000_target_105_seed_0.png',
#  'action_hist_episode_40000_target_105_seed_0.npy',
#  'embeddings_ep_50000_target_105_seed_0.png',
#  'action_hist_episode_50000_target_105_seed_0.npy',
#  'embeddings_ep_60000_target_105_seed_0.png',
#  'action_hist_episode_60000_target_105_seed_0.npy',
#  'embeddings_ep_70000_target_105_seed_0.png',
#  'action_hist_episode_70000_target_105_seed_0.npy',
#  'embeddings_ep_80000_target_105_seed_0.png',
#  'action_hist_episode_80000_target_105_seed_0.npy',
#  'embeddings_ep_90000_target_105_seed_0.png',
#  'action_hist_episode_90000_target_105_seed_0.npy',
#  'embeddings_ep_100000_target_105_seed_0.png',
#  'action_hist_episode_100000_target_105_seed_0.npy',
#  'embeddings_ep_110000_target_105_seed_0.png',
#  'action_hist_episode_110000_target_105_seed_0.npy',
#  'embeddings_ep_120000_target_105_seed_0.png',
#  'action_hist_episode_120000_target_105_seed_0.npy',
#  'embeddings_ep_130000_target_105_seed_0.png',
#  'action_hist_episode_130000_target_105_seed_0.npy',
#  'embeddings_ep_140000_target_105_seed_0.png',
#  'action_hist_episode_140000_target_105_seed_0.npy',
#  'embeddings_ep_150000_target_105_seed_0.png',
#  'action_hist_episode_150000_target_105_seed_0.npy',
#  'embeddings_ep_160000_target_105_seed_0.png',
#  'action_hist_episode_160000_target_105_seed_0.npy',
#  'embeddings_ep_170000_target_105_seed_0.png',
#  'action_hist_episode_170000_target_105_seed_0.npy',
#  'embeddings_ep_180000_target_105_seed_0.png',
#  'action_hist_episode_180000_target_105_seed_0.npy',
#  'embeddings_ep_190000_target_105_seed_0.png',
#  'action_hist_episode_190000_target_105_seed_0.npy',
#  'critic_loss_target_105_seed_0.npy',
#  'loss_target_105_seed_0.pdf',
#  'angle_differences_target_105_seed_0.npy',
#  'angular_error_target_105_seed_0.pdf',
#  'embeddings_ep_0_target_120_seed_0.png',
#  'action_hist_episode_0_target_120_seed_0.npy',
#  'action_hist_0_target_120_seed_0.pdf',
#  'embeddings_ep_10000_target_120_seed_0.png',
#  'action_hist_episode_10000_target_120_seed_0.npy',
#  'embeddings_ep_20000_target_120_seed_0.png',
#  'action_hist_episode_20000_target_120_seed_0.npy',
#  'embeddings_ep_30000_target_120_seed_0.png',
#  'action_hist_episode_30000_target_120_seed_0.npy',
#  'embeddings_ep_40000_target_120_seed_0.png',
#  'action_hist_episode_40000_target_120_seed_0.npy',
#  'embeddings_ep_50000_target_120_seed_0.png',
#  'action_hist_episode_50000_target_120_seed_0.npy',
#  'embeddings_ep_60000_target_120_seed_0.png',
#  'action_hist_episode_60000_target_120_seed_0.npy',
#  'embeddings_ep_70000_target_120_seed_0.png',
#  'action_hist_episode_70000_target_120_seed_0.npy',
#  'embeddings_ep_80000_target_120_seed_0.png',
#  'action_hist_episode_80000_target_120_seed_0.npy',
#  'embeddings_ep_90000_target_120_seed_0.png',
#  'action_hist_episode_90000_target_120_seed_0.npy',
#  'embeddings_ep_100000_target_120_seed_0.png',
#  'action_hist_episode_100000_target_120_seed_0.npy',
#  'embeddings_ep_110000_target_120_seed_0.png',
#  'action_hist_episode_110000_target_120_seed_0.npy',
#  'embeddings_ep_120000_target_120_seed_0.png',
#  'action_hist_episode_120000_target_120_seed_0.npy',
#  'embeddings_ep_130000_target_120_seed_0.png',
#  'action_hist_episode_130000_target_120_seed_0.npy',
#  'embeddings_ep_140000_target_120_seed_0.png',
#  'action_hist_episode_140000_target_120_seed_0.npy',
#  'embeddings_ep_150000_target_120_seed_0.png',
#  'action_hist_episode_150000_target_120_seed_0.npy',
#  'embeddings_ep_160000_target_120_seed_0.png',
#  'action_hist_episode_160000_target_120_seed_0.npy',
#  'embeddings_ep_170000_target_120_seed_0.png',
#  'action_hist_episode_170000_target_120_seed_0.npy',
#  'embeddings_ep_180000_target_120_seed_0.png',
#  'action_hist_episode_180000_target_120_seed_0.npy',
#  'embeddings_ep_190000_target_120_seed_0.png',
#  'action_hist_episode_190000_target_120_seed_0.npy',
#  'critic_loss_target_120_seed_0.npy',
#  'loss_target_120_seed_0.pdf',
#  'angle_differences_target_120_seed_0.npy',
#  'angular_error_target_120_seed_0.pdf',
#  'embeddings_ep_0_target_135_seed_0.png',
#  'action_hist_episode_0_target_135_seed_0.npy',
#  'action_hist_0_target_135_seed_0.pdf',
#  'embeddings_ep_10000_target_135_seed_0.png',
#  'action_hist_episode_10000_target_135_seed_0.npy',
#  'embeddings_ep_20000_target_135_seed_0.png',
#  'action_hist_episode_20000_target_135_seed_0.npy',
#  'embeddings_ep_30000_target_135_seed_0.png',
#  'action_hist_episode_30000_target_135_seed_0.npy',
#  'embeddings_ep_40000_target_135_seed_0.png',
#  'action_hist_episode_40000_target_135_seed_0.npy',
#  'embeddings_ep_50000_target_135_seed_0.png',
#  'action_hist_episode_50000_target_135_seed_0.npy',
#  'embeddings_ep_60000_target_135_seed_0.png',
#  'action_hist_episode_60000_target_135_seed_0.npy',
#  'embeddings_ep_70000_target_135_seed_0.png',
#  'action_hist_episode_70000_target_135_seed_0.npy',
#  'embeddings_ep_80000_target_135_seed_0.png',
#  'action_hist_episode_80000_target_135_seed_0.npy',
#  'embeddings_ep_90000_target_135_seed_0.png',
#  'action_hist_episode_90000_target_135_seed_0.npy',
#  'embeddings_ep_100000_target_135_seed_0.png',
#  'action_hist_episode_100000_target_135_seed_0.npy',
#  'embeddings_ep_110000_target_135_seed_0.png',
#  'action_hist_episode_110000_target_135_seed_0.npy',
#  'embeddings_ep_120000_target_135_seed_0.png',
#  'action_hist_episode_120000_target_135_seed_0.npy',
#  'embeddings_ep_130000_target_135_seed_0.png',
#  'action_hist_episode_130000_target_135_seed_0.npy',
#  'embeddings_ep_140000_target_135_seed_0.png',
#  'action_hist_episode_140000_target_135_seed_0.npy',
#  'embeddings_ep_150000_target_135_seed_0.png',
#  'action_hist_episode_150000_target_135_seed_0.npy',
#  'embeddings_ep_160000_target_135_seed_0.png',
#  'action_hist_episode_160000_target_135_seed_0.npy',
#  'embeddings_ep_170000_target_135_seed_0.png',
#  'action_hist_episode_170000_target_135_seed_0.npy',
#  'embeddings_ep_180000_target_135_seed_0.png',
#  'action_hist_episode_180000_target_135_seed_0.npy',
#  'embeddings_ep_190000_target_135_seed_0.png',
#  'action_hist_episode_190000_target_135_seed_0.npy',
#  'critic_loss_target_135_seed_0.npy',
#  'loss_target_135_seed_0.pdf',
#  'angle_differences_target_135_seed_0.npy',
#  'angular_error_target_135_seed_0.pdf',
#  'embeddings_ep_0_target_150_seed_0.png',
#  'action_hist_episode_0_target_150_seed_0.npy',
#  'action_hist_0_target_150_seed_0.pdf',
#  'embeddings_ep_10000_target_150_seed_0.png',
#  'action_hist_episode_10000_target_150_seed_0.npy',
#  'embeddings_ep_20000_target_150_seed_0.png',
#  'action_hist_episode_20000_target_150_seed_0.npy',
#  'embeddings_ep_30000_target_150_seed_0.png',
#  'action_hist_episode_30000_target_150_seed_0.npy',
#  'embeddings_ep_40000_target_150_seed_0.png',
#  'action_hist_episode_40000_target_150_seed_0.npy',
#  'embeddings_ep_50000_target_150_seed_0.png',
#  'action_hist_episode_50000_target_150_seed_0.npy',
#  'embeddings_ep_60000_target_150_seed_0.png',
#  'action_hist_episode_60000_target_150_seed_0.npy',
#  'embeddings_ep_70000_target_150_seed_0.png',
#  'action_hist_episode_70000_target_150_seed_0.npy',
#  'embeddings_ep_80000_target_150_seed_0.png',
#  'action_hist_episode_80000_target_150_seed_0.npy',
#  'embeddings_ep_90000_target_150_seed_0.png',
#  'action_hist_episode_90000_target_150_seed_0.npy',
#  'embeddings_ep_100000_target_150_seed_0.png',
#  'action_hist_episode_100000_target_150_seed_0.npy',
#  'embeddings_ep_110000_target_150_seed_0.png',
#  'action_hist_episode_110000_target_150_seed_0.npy',
#  'embeddings_ep_120000_target_150_seed_0.png',
#  'action_hist_episode_120000_target_150_seed_0.npy',
#  'embeddings_ep_130000_target_150_seed_0.png',
#  'action_hist_episode_130000_target_150_seed_0.npy',
#  'embeddings_ep_140000_target_150_seed_0.png',
#  'action_hist_episode_140000_target_150_seed_0.npy',
#  'embeddings_ep_150000_target_150_seed_0.png',
#  'action_hist_episode_150000_target_150_seed_0.npy',
#  'embeddings_ep_160000_target_150_seed_0.png',
#  'action_hist_episode_160000_target_150_seed_0.npy',
#  'embeddings_ep_170000_target_150_seed_0.png',
#  'action_hist_episode_170000_target_150_seed_0.npy',
#  'embeddings_ep_180000_target_150_seed_0.png',
#  'action_hist_episode_180000_target_150_seed_0.npy',
#  'embeddings_ep_190000_target_150_seed_0.png',
#  'action_hist_episode_190000_target_150_seed_0.npy',
#  'critic_loss_target_150_seed_0.npy',
#  'loss_target_150_seed_0.pdf',
#  'angle_differences_target_150_seed_0.npy',
#  'angular_error_target_150_seed_0.pdf',
#  'embeddings_ep_0_target_165_seed_0.png',
#  'action_hist_episode_0_target_165_seed_0.npy',
#  'action_hist_0_target_165_seed_0.pdf',
#  'embeddings_ep_10000_target_165_seed_0.png',
#  'action_hist_episode_10000_target_165_seed_0.npy',
#  'embeddings_ep_20000_target_165_seed_0.png',
#  'action_hist_episode_20000_target_165_seed_0.npy',
#  'embeddings_ep_30000_target_165_seed_0.png',
#  'action_hist_episode_30000_target_165_seed_0.npy',
#  'embeddings_ep_40000_target_165_seed_0.png',
#  'action_hist_episode_40000_target_165_seed_0.npy',
#  'embeddings_ep_50000_target_165_seed_0.png',
#  'action_hist_episode_50000_target_165_seed_0.npy',
#  'embeddings_ep_60000_target_165_seed_0.png',
#  'action_hist_episode_60000_target_165_seed_0.npy',
#  'embeddings_ep_70000_target_165_seed_0.png',
#  'action_hist_episode_70000_target_165_seed_0.npy',
#  'embeddings_ep_80000_target_165_seed_0.png',
#  'action_hist_episode_80000_target_165_seed_0.npy',
#  'embeddings_ep_90000_target_165_seed_0.png',
#  'action_hist_episode_90000_target_165_seed_0.npy',
#  'embeddings_ep_100000_target_165_seed_0.png',
#  'action_hist_episode_100000_target_165_seed_0.npy',
#  'embeddings_ep_110000_target_165_seed_0.png',
#  'action_hist_episode_110000_target_165_seed_0.npy',
#  'embeddings_ep_120000_target_165_seed_0.png',
#  'action_hist_episode_120000_target_165_seed_0.npy',
#  'embeddings_ep_130000_target_165_seed_0.png',
#  'action_hist_episode_130000_target_165_seed_0.npy',
#  'embeddings_ep_140000_target_165_seed_0.png',
#  'action_hist_episode_140000_target_165_seed_0.npy',
#  'embeddings_ep_150000_target_165_seed_0.png',
#  'action_hist_episode_150000_target_165_seed_0.npy',
#  'embeddings_ep_160000_target_165_seed_0.png',
#  'action_hist_episode_160000_target_165_seed_0.npy',
#  'embeddings_ep_170000_target_165_seed_0.png',
#  'action_hist_episode_170000_target_165_seed_0.npy',
#  'embeddings_ep_180000_target_165_seed_0.png',
#  'action_hist_episode_180000_target_165_seed_0.npy',
#  'embeddings_ep_190000_target_165_seed_0.png',
#  'action_hist_episode_190000_target_165_seed_0.npy',
#  'critic_loss_target_165_seed_0.npy',
#  'loss_target_165_seed_0.pdf',
#  'angle_differences_target_165_seed_0.npy',
#  'angular_error_target_165_seed_0.pdf',
#  'embeddings_ep_0_target_180_seed_0.png',
#  'action_hist_episode_0_target_180_seed_0.npy',
#  'action_hist_0_target_180_seed_0.pdf',
#  'embeddings_ep_10000_target_180_seed_0.png',
#  'action_hist_episode_10000_target_180_seed_0.npy',
#  'embeddings_ep_20000_target_180_seed_0.png',
#  'action_hist_episode_20000_target_180_seed_0.npy',
#  'embeddings_ep_30000_target_180_seed_0.png',
#  'action_hist_episode_30000_target_180_seed_0.npy',
#  'embeddings_ep_40000_target_180_seed_0.png',
#  'action_hist_episode_40000_target_180_seed_0.npy',
#  'embeddings_ep_50000_target_180_seed_0.png',
#  'action_hist_episode_50000_target_180_seed_0.npy',
#  'embeddings_ep_60000_target_180_seed_0.png',
#  'action_hist_episode_60000_target_180_seed_0.npy',
#  'embeddings_ep_70000_target_180_seed_0.png',
#  'action_hist_episode_70000_target_180_seed_0.npy',
#  'embeddings_ep_80000_target_180_seed_0.png',
#  'action_hist_episode_80000_target_180_seed_0.npy',
#  'embeddings_ep_90000_target_180_seed_0.png',
#  'action_hist_episode_90000_target_180_seed_0.npy',
#  'embeddings_ep_100000_target_180_seed_0.png',
#  'action_hist_episode_100000_target_180_seed_0.npy',
#  'embeddings_ep_110000_target_180_seed_0.png',
#  'action_hist_episode_110000_target_180_seed_0.npy',
#  'embeddings_ep_120000_target_180_seed_0.png',
#  'action_hist_episode_120000_target_180_seed_0.npy',
#  'embeddings_ep_130000_target_180_seed_0.png',
#  'action_hist_episode_130000_target_180_seed_0.npy',
#  'embeddings_ep_140000_target_180_seed_0.png',
#  'action_hist_episode_140000_target_180_seed_0.npy',
#  'embeddings_ep_150000_target_180_seed_0.png',
#  'action_hist_episode_150000_target_180_seed_0.npy',
#  'embeddings_ep_160000_target_180_seed_0.png',
#  'action_hist_episode_160000_target_180_seed_0.npy',
#  'embeddings_ep_170000_target_180_seed_0.png',
#  'action_hist_episode_170000_target_180_seed_0.npy',
#  'embeddings_ep_180000_target_180_seed_0.png',
#  'action_hist_episode_180000_target_180_seed_0.npy',
#  'embeddings_ep_190000_target_180_seed_0.png',
#  'action_hist_episode_190000_target_180_seed_0.npy',
#  'critic_loss_target_180_seed_0.npy',
#  'loss_target_180_seed_0.pdf',
#  'angle_differences_target_180_seed_0.npy',
#  'angular_error_target_180_seed_0.pdf',
#  'embeddings_ep_0_target_195_seed_0.png',
#  'action_hist_episode_0_target_195_seed_0.npy',
#  'action_hist_0_target_195_seed_0.pdf',
#  'embeddings_ep_10000_target_195_seed_0.png',
#  'action_hist_episode_10000_target_195_seed_0.npy',
#  'embeddings_ep_20000_target_195_seed_0.png',
#  'action_hist_episode_20000_target_195_seed_0.npy',
#  'embeddings_ep_30000_target_195_seed_0.png',
#  'action_hist_episode_30000_target_195_seed_0.npy',
#  'embeddings_ep_40000_target_195_seed_0.png',
#  'action_hist_episode_40000_target_195_seed_0.npy',
#  'embeddings_ep_50000_target_195_seed_0.png',
#  'action_hist_episode_50000_target_195_seed_0.npy',
#  'embeddings_ep_60000_target_195_seed_0.png',
#  'action_hist_episode_60000_target_195_seed_0.npy',
#  'embeddings_ep_70000_target_195_seed_0.png',
#  'action_hist_episode_70000_target_195_seed_0.npy',
#  'embeddings_ep_80000_target_195_seed_0.png',
#  'action_hist_episode_80000_target_195_seed_0.npy',
#  'embeddings_ep_90000_target_195_seed_0.png',
#  'action_hist_episode_90000_target_195_seed_0.npy',
#  'embeddings_ep_100000_target_195_seed_0.png',
#  'action_hist_episode_100000_target_195_seed_0.npy',
#  'embeddings_ep_110000_target_195_seed_0.png',
#  'action_hist_episode_110000_target_195_seed_0.npy',
#  'embeddings_ep_120000_target_195_seed_0.png',
#  'action_hist_episode_120000_target_195_seed_0.npy',
#  'embeddings_ep_130000_target_195_seed_0.png',
#  'action_hist_episode_130000_target_195_seed_0.npy',
#  'embeddings_ep_140000_target_195_seed_0.png',
#  'action_hist_episode_140000_target_195_seed_0.npy',
#  'embeddings_ep_150000_target_195_seed_0.png',
#  'action_hist_episode_150000_target_195_seed_0.npy',
#  'embeddings_ep_160000_target_195_seed_0.png',
#  'action_hist_episode_160000_target_195_seed_0.npy',
#  'embeddings_ep_170000_target_195_seed_0.png',
#  'action_hist_episode_170000_target_195_seed_0.npy',
#  'embeddings_ep_180000_target_195_seed_0.png',
#  'action_hist_episode_180000_target_195_seed_0.npy',
#  'embeddings_ep_190000_target_195_seed_0.png',
#  'action_hist_episode_190000_target_195_seed_0.npy',
#  'critic_loss_target_195_seed_0.npy',
#  'loss_target_195_seed_0.pdf',
#  'angle_differences_target_195_seed_0.npy',
#  'angular_error_target_195_seed_0.pdf',
#  'embeddings_ep_0_target_210_seed_0.png',
#  'action_hist_episode_0_target_210_seed_0.npy',
#  'action_hist_0_target_210_seed_0.pdf',
#  'embeddings_ep_10000_target_210_seed_0.png',
#  'action_hist_episode_10000_target_210_seed_0.npy',
#  'embeddings_ep_20000_target_210_seed_0.png',
#  'action_hist_episode_20000_target_210_seed_0.npy',
#  'embeddings_ep_30000_target_210_seed_0.png',
#  'action_hist_episode_30000_target_210_seed_0.npy',
#  'embeddings_ep_40000_target_210_seed_0.png',
#  'action_hist_episode_40000_target_210_seed_0.npy',
#  'embeddings_ep_50000_target_210_seed_0.png',
#  'action_hist_episode_50000_target_210_seed_0.npy',
#  'embeddings_ep_60000_target_210_seed_0.png',
#  'action_hist_episode_60000_target_210_seed_0.npy',
#  'embeddings_ep_70000_target_210_seed_0.png',
#  'action_hist_episode_70000_target_210_seed_0.npy',
#  'embeddings_ep_80000_target_210_seed_0.png',
#  'action_hist_episode_80000_target_210_seed_0.npy',
#  'embeddings_ep_90000_target_210_seed_0.png',
#  'action_hist_episode_90000_target_210_seed_0.npy',
#  'embeddings_ep_100000_target_210_seed_0.png',
#  'action_hist_episode_100000_target_210_seed_0.npy',
#  'embeddings_ep_110000_target_210_seed_0.png',
#  'action_hist_episode_110000_target_210_seed_0.npy',
#  'embeddings_ep_120000_target_210_seed_0.png',
#  'action_hist_episode_120000_target_210_seed_0.npy',
#  'embeddings_ep_130000_target_210_seed_0.png',
#  'action_hist_episode_130000_target_210_seed_0.npy',
#  'embeddings_ep_140000_target_210_seed_0.png',
#  'action_hist_episode_140000_target_210_seed_0.npy',
#  'embeddings_ep_150000_target_210_seed_0.png',
#  'action_hist_episode_150000_target_210_seed_0.npy',
#  'embeddings_ep_160000_target_210_seed_0.png',
#  'action_hist_episode_160000_target_210_seed_0.npy',
#  'embeddings_ep_170000_target_210_seed_0.png',
#  'action_hist_episode_170000_target_210_seed_0.npy',
#  'embeddings_ep_180000_target_210_seed_0.png',
#  'action_hist_episode_180000_target_210_seed_0.npy',
#  'embeddings_ep_190000_target_210_seed_0.png',
#  'action_hist_episode_190000_target_210_seed_0.npy',
#  'critic_loss_target_210_seed_0.npy',
#  'loss_target_210_seed_0.pdf',
#  'angle_differences_target_210_seed_0.npy',
#  'angular_error_target_210_seed_0.pdf',
#  'embeddings_ep_0_target_225_seed_0.png',
#  'action_hist_episode_0_target_225_seed_0.npy',
#  'action_hist_0_target_225_seed_0.pdf',
#  'embeddings_ep_10000_target_225_seed_0.png',
#  'action_hist_episode_10000_target_225_seed_0.npy',
#  'embeddings_ep_20000_target_225_seed_0.png',
#  'action_hist_episode_20000_target_225_seed_0.npy',
#  'embeddings_ep_30000_target_225_seed_0.png',
#  'action_hist_episode_30000_target_225_seed_0.npy',
#  'embeddings_ep_40000_target_225_seed_0.png',
#  'action_hist_episode_40000_target_225_seed_0.npy',
#  'embeddings_ep_50000_target_225_seed_0.png',
#  'action_hist_episode_50000_target_225_seed_0.npy',
#  'embeddings_ep_60000_target_225_seed_0.png',
#  'action_hist_episode_60000_target_225_seed_0.npy',
#  'embeddings_ep_70000_target_225_seed_0.png',
#  'action_hist_episode_70000_target_225_seed_0.npy',
#  'embeddings_ep_80000_target_225_seed_0.png',
#  'action_hist_episode_80000_target_225_seed_0.npy',
#  'embeddings_ep_90000_target_225_seed_0.png',
#  'action_hist_episode_90000_target_225_seed_0.npy',
#  'embeddings_ep_100000_target_225_seed_0.png',
#  'action_hist_episode_100000_target_225_seed_0.npy',
#  'embeddings_ep_110000_target_225_seed_0.png',
#  'action_hist_episode_110000_target_225_seed_0.npy',
#  'embeddings_ep_120000_target_225_seed_0.png',
#  'action_hist_episode_120000_target_225_seed_0.npy',
#  'embeddings_ep_130000_target_225_seed_0.png',
#  'action_hist_episode_130000_target_225_seed_0.npy',
#  'embeddings_ep_140000_target_225_seed_0.png',
#  'action_hist_episode_140000_target_225_seed_0.npy',
#  'embeddings_ep_150000_target_225_seed_0.png',
#  'action_hist_episode_150000_target_225_seed_0.npy',
#  'embeddings_ep_160000_target_225_seed_0.png',
#  'action_hist_episode_160000_target_225_seed_0.npy',
#  'embeddings_ep_170000_target_225_seed_0.png',
#  'action_hist_episode_170000_target_225_seed_0.npy',
#  'embeddings_ep_180000_target_225_seed_0.png',
#  'action_hist_episode_180000_target_225_seed_0.npy',
#  'embeddings_ep_190000_target_225_seed_0.png',
#  'action_hist_episode_190000_target_225_seed_0.npy',
#  'critic_loss_target_225_seed_0.npy',
#  'loss_target_225_seed_0.pdf',
#  'angle_differences_target_225_seed_0.npy',
#  'angular_error_target_225_seed_0.pdf',
#  'embeddings_ep_0_target_240_seed_0.png',
#  'action_hist_episode_0_target_240_seed_0.npy',
#  'action_hist_0_target_240_seed_0.pdf',
#  'embeddings_ep_10000_target_240_seed_0.png',
#  'action_hist_episode_10000_target_240_seed_0.npy',
#  'embeddings_ep_20000_target_240_seed_0.png',
#  'action_hist_episode_20000_target_240_seed_0.npy',
#  'embeddings_ep_30000_target_240_seed_0.png',
#  'action_hist_episode_30000_target_240_seed_0.npy',
#  'embeddings_ep_40000_target_240_seed_0.png',
#  'action_hist_episode_40000_target_240_seed_0.npy',
#  'embeddings_ep_50000_target_240_seed_0.png',
#  'action_hist_episode_50000_target_240_seed_0.npy',
#  'embeddings_ep_60000_target_240_seed_0.png',
#  'action_hist_episode_60000_target_240_seed_0.npy',
#  'embeddings_ep_70000_target_240_seed_0.png',
#  'action_hist_episode_70000_target_240_seed_0.npy',
#  'embeddings_ep_80000_target_240_seed_0.png',
#  'action_hist_episode_80000_target_240_seed_0.npy',
#  'embeddings_ep_90000_target_240_seed_0.png',
#  'action_hist_episode_90000_target_240_seed_0.npy',
#  'embeddings_ep_100000_target_240_seed_0.png',
#  'action_hist_episode_100000_target_240_seed_0.npy',
#  'embeddings_ep_110000_target_240_seed_0.png',
#  'action_hist_episode_110000_target_240_seed_0.npy',
#  'embeddings_ep_120000_target_240_seed_0.png',
#  'action_hist_episode_120000_target_240_seed_0.npy',
#  'embeddings_ep_130000_target_240_seed_0.png',
#  'action_hist_episode_130000_target_240_seed_0.npy',
#  'embeddings_ep_140000_target_240_seed_0.png',
#  'action_hist_episode_140000_target_240_seed_0.npy',
#  'embeddings_ep_150000_target_240_seed_0.png',
#  'action_hist_episode_150000_target_240_seed_0.npy',
#  'embeddings_ep_160000_target_240_seed_0.png',
#  'action_hist_episode_160000_target_240_seed_0.npy',
#  'embeddings_ep_170000_target_240_seed_0.png',
#  'action_hist_episode_170000_target_240_seed_0.npy',
#  'embeddings_ep_180000_target_240_seed_0.png',
#  'action_hist_episode_180000_target_240_seed_0.npy',
#  'embeddings_ep_190000_target_240_seed_0.png',
#  'action_hist_episode_190000_target_240_seed_0.npy',
#  'critic_loss_target_240_seed_0.npy',
#  'loss_target_240_seed_0.pdf',
#  'angle_differences_target_240_seed_0.npy',
#  'angular_error_target_240_seed_0.pdf',
#  'embeddings_ep_0_target_255_seed_0.png',
#  'action_hist_episode_0_target_255_seed_0.npy',
#  'action_hist_0_target_255_seed_0.pdf',
#  'embeddings_ep_10000_target_255_seed_0.png',
#  'action_hist_episode_10000_target_255_seed_0.npy',
#  'embeddings_ep_20000_target_255_seed_0.png',
#  'action_hist_episode_20000_target_255_seed_0.npy',
#  'embeddings_ep_30000_target_255_seed_0.png',
#  'action_hist_episode_30000_target_255_seed_0.npy',
#  'embeddings_ep_40000_target_255_seed_0.png',
#  'action_hist_episode_40000_target_255_seed_0.npy',
#  'embeddings_ep_50000_target_255_seed_0.png',
#  'action_hist_episode_50000_target_255_seed_0.npy',
#  'embeddings_ep_60000_target_255_seed_0.png',
#  'action_hist_episode_60000_target_255_seed_0.npy',
#  'embeddings_ep_70000_target_255_seed_0.png',
#  'action_hist_episode_70000_target_255_seed_0.npy',
#  'embeddings_ep_80000_target_255_seed_0.png',
#  'action_hist_episode_80000_target_255_seed_0.npy',
#  'embeddings_ep_90000_target_255_seed_0.png',
#  'action_hist_episode_90000_target_255_seed_0.npy',
#  'embeddings_ep_100000_target_255_seed_0.png',
#  'action_hist_episode_100000_target_255_seed_0.npy',
#  'embeddings_ep_110000_target_255_seed_0.png',
#  'action_hist_episode_110000_target_255_seed_0.npy',
#  'embeddings_ep_120000_target_255_seed_0.png',
#  'action_hist_episode_120000_target_255_seed_0.npy',
#  'embeddings_ep_130000_target_255_seed_0.png',
#  'action_hist_episode_130000_target_255_seed_0.npy',
#  'embeddings_ep_140000_target_255_seed_0.png',
#  'action_hist_episode_140000_target_255_seed_0.npy',
#  'embeddings_ep_150000_target_255_seed_0.png',
#  'action_hist_episode_150000_target_255_seed_0.npy',
#  'embeddings_ep_160000_target_255_seed_0.png',
#  'action_hist_episode_160000_target_255_seed_0.npy',
#  'embeddings_ep_170000_target_255_seed_0.png',
#  'action_hist_episode_170000_target_255_seed_0.npy',
#  'embeddings_ep_180000_target_255_seed_0.png',
#  'action_hist_episode_180000_target_255_seed_0.npy',
#  'embeddings_ep_190000_target_255_seed_0.png',
#  'action_hist_episode_190000_target_255_seed_0.npy',
#  'critic_loss_target_255_seed_0.npy',
#  'loss_target_255_seed_0.pdf',
#  'angle_differences_target_255_seed_0.npy',
#  'angular_error_target_255_seed_0.pdf',
#  'embeddings_ep_0_target_270_seed_0.png',
#  'action_hist_episode_0_target_270_seed_0.npy',
#  'action_hist_0_target_270_seed_0.pdf',
#  'embeddings_ep_10000_target_270_seed_0.png',
#  'action_hist_episode_10000_target_270_seed_0.npy',
#  'embeddings_ep_20000_target_270_seed_0.png',
#  'action_hist_episode_20000_target_270_seed_0.npy',
#  'embeddings_ep_30000_target_270_seed_0.png',
#  'action_hist_episode_30000_target_270_seed_0.npy',
#  'embeddings_ep_40000_target_270_seed_0.png',
#  'action_hist_episode_40000_target_270_seed_0.npy',
#  'embeddings_ep_50000_target_270_seed_0.png',
#  'action_hist_episode_50000_target_270_seed_0.npy',
#  'embeddings_ep_60000_target_270_seed_0.png',
#  'action_hist_episode_60000_target_270_seed_0.npy',
#  'embeddings_ep_70000_target_270_seed_0.png',
#  'action_hist_episode_70000_target_270_seed_0.npy',
#  'embeddings_ep_80000_target_270_seed_0.png',
#  'action_hist_episode_80000_target_270_seed_0.npy',
#  'embeddings_ep_90000_target_270_seed_0.png',
#  'action_hist_episode_90000_target_270_seed_0.npy',
#  'embeddings_ep_100000_target_270_seed_0.png',
#  'action_hist_episode_100000_target_270_seed_0.npy',
#  'embeddings_ep_110000_target_270_seed_0.png',
#  'action_hist_episode_110000_target_270_seed_0.npy',
#  'embeddings_ep_120000_target_270_seed_0.png',
#  'action_hist_episode_120000_target_270_seed_0.npy',
#  'embeddings_ep_130000_target_270_seed_0.png',
#  'action_hist_episode_130000_target_270_seed_0.npy',
#  'embeddings_ep_140000_target_270_seed_0.png',
#  'action_hist_episode_140000_target_270_seed_0.npy',
#  'embeddings_ep_150000_target_270_seed_0.png',
#  'action_hist_episode_150000_target_270_seed_0.npy',
#  'embeddings_ep_160000_target_270_seed_0.png',
#  'action_hist_episode_160000_target_270_seed_0.npy',
#  'embeddings_ep_170000_target_270_seed_0.png',
#  'action_hist_episode_170000_target_270_seed_0.npy',
#  'embeddings_ep_180000_target_270_seed_0.png',
#  'action_hist_episode_180000_target_270_seed_0.npy',
#  'embeddings_ep_190000_target_270_seed_0.png',
#  'action_hist_episode_190000_target_270_seed_0.npy',
#  'critic_loss_target_270_seed_0.npy',
#  'loss_target_270_seed_0.pdf',
#  'angle_differences_target_270_seed_0.npy',
#  'angular_error_target_270_seed_0.pdf',
#  'embeddings_ep_0_target_285_seed_0.png',
#  'action_hist_episode_0_target_285_seed_0.npy',
#  'action_hist_0_target_285_seed_0.pdf',
#  'embeddings_ep_10000_target_285_seed_0.png',
#  'action_hist_episode_10000_target_285_seed_0.npy',
#  'embeddings_ep_20000_target_285_seed_0.png',
#  'action_hist_episode_20000_target_285_seed_0.npy',
#  'embeddings_ep_30000_target_285_seed_0.png',
#  'action_hist_episode_30000_target_285_seed_0.npy',
#  'embeddings_ep_40000_target_285_seed_0.png',
#  'action_hist_episode_40000_target_285_seed_0.npy',
#  'embeddings_ep_50000_target_285_seed_0.png',
#  'action_hist_episode_50000_target_285_seed_0.npy',
#  'embeddings_ep_60000_target_285_seed_0.png',
#  'action_hist_episode_60000_target_285_seed_0.npy',
#  'embeddings_ep_70000_target_285_seed_0.png',
#  'action_hist_episode_70000_target_285_seed_0.npy',
#  'embeddings_ep_80000_target_285_seed_0.png',
#  'action_hist_episode_80000_target_285_seed_0.npy',
#  'embeddings_ep_90000_target_285_seed_0.png',
#  'action_hist_episode_90000_target_285_seed_0.npy',
#  'embeddings_ep_100000_target_285_seed_0.png',
#  'action_hist_episode_100000_target_285_seed_0.npy',
#  'embeddings_ep_110000_target_285_seed_0.png',
#  'action_hist_episode_110000_target_285_seed_0.npy',
#  'embeddings_ep_120000_target_285_seed_0.png',
#  'action_hist_episode_120000_target_285_seed_0.npy',
#  'embeddings_ep_130000_target_285_seed_0.png',
#  'action_hist_episode_130000_target_285_seed_0.npy',
#  'embeddings_ep_140000_target_285_seed_0.png',
#  'action_hist_episode_140000_target_285_seed_0.npy',
#  'embeddings_ep_150000_target_285_seed_0.png',
#  'action_hist_episode_150000_target_285_seed_0.npy',
#  'embeddings_ep_160000_target_285_seed_0.png',
#  'action_hist_episode_160000_target_285_seed_0.npy',
#  'embeddings_ep_170000_target_285_seed_0.png',
#  'action_hist_episode_170000_target_285_seed_0.npy',
#  'embeddings_ep_180000_target_285_seed_0.png',
#  'action_hist_episode_180000_target_285_seed_0.npy',
#  'embeddings_ep_190000_target_285_seed_0.png',
#  'action_hist_episode_190000_target_285_seed_0.npy',
#  'critic_loss_target_285_seed_0.npy',
#  'loss_target_285_seed_0.pdf',
#  'angle_differences_target_285_seed_0.npy',
#  'angular_error_target_285_seed_0.pdf',
#  'embeddings_ep_0_target_300_seed_0.png',
#  'action_hist_episode_0_target_300_seed_0.npy',
#  'action_hist_0_target_300_seed_0.pdf',
#  'embeddings_ep_10000_target_300_seed_0.png',
#  'action_hist_episode_10000_target_300_seed_0.npy',
#  'embeddings_ep_20000_target_300_seed_0.png',
#  'action_hist_episode_20000_target_300_seed_0.npy',
#  'embeddings_ep_30000_target_300_seed_0.png',
#  'action_hist_episode_30000_target_300_seed_0.npy',
#  'embeddings_ep_40000_target_300_seed_0.png',
#  'action_hist_episode_40000_target_300_seed_0.npy',
#  'embeddings_ep_50000_target_300_seed_0.png',
#  'action_hist_episode_50000_target_300_seed_0.npy',
#  'embeddings_ep_60000_target_300_seed_0.png',
#  'action_hist_episode_60000_target_300_seed_0.npy',
#  'embeddings_ep_70000_target_300_seed_0.png',
#  'action_hist_episode_70000_target_300_seed_0.npy',
#  'embeddings_ep_80000_target_300_seed_0.png',
#  'action_hist_episode_80000_target_300_seed_0.npy',
#  'embeddings_ep_90000_target_300_seed_0.png',
#  'action_hist_episode_90000_target_300_seed_0.npy',
#  'embeddings_ep_100000_target_300_seed_0.png',
#  'action_hist_episode_100000_target_300_seed_0.npy',
#  'embeddings_ep_110000_target_300_seed_0.png',
#  'action_hist_episode_110000_target_300_seed_0.npy',
#  'embeddings_ep_120000_target_300_seed_0.png',
#  'action_hist_episode_120000_target_300_seed_0.npy',
#  'embeddings_ep_130000_target_300_seed_0.png',
#  'action_hist_episode_130000_target_300_seed_0.npy',
#  'embeddings_ep_140000_target_300_seed_0.png',
#  'action_hist_episode_140000_target_300_seed_0.npy',
#  'embeddings_ep_150000_target_300_seed_0.png',
#  'action_hist_episode_150000_target_300_seed_0.npy',
#  'embeddings_ep_160000_target_300_seed_0.png',
#  'action_hist_episode_160000_target_300_seed_0.npy',
#  'embeddings_ep_170000_target_300_seed_0.png',
#  'action_hist_episode_170000_target_300_seed_0.npy',
#  'embeddings_ep_180000_target_300_seed_0.png',
#  'action_hist_episode_180000_target_300_seed_0.npy',
#  'embeddings_ep_190000_target_300_seed_0.png',
#  'action_hist_episode_190000_target_300_seed_0.npy',
#  'critic_loss_target_300_seed_0.npy',
#  'loss_target_300_seed_0.pdf',
#  'angle_differences_target_300_seed_0.npy',
#  'angular_error_target_300_seed_0.pdf',
#  'embeddings_ep_0_target_315_seed_0.png',
#  'action_hist_episode_0_target_315_seed_0.npy',
#  'action_hist_0_target_315_seed_0.pdf',
#  'embeddings_ep_10000_target_315_seed_0.png',
#  'action_hist_episode_10000_target_315_seed_0.npy',
#  'embeddings_ep_20000_target_315_seed_0.png',
#  'action_hist_episode_20000_target_315_seed_0.npy',
#  'embeddings_ep_30000_target_315_seed_0.png',
#  'action_hist_episode_30000_target_315_seed_0.npy',
#  'embeddings_ep_40000_target_315_seed_0.png',
#  'action_hist_episode_40000_target_315_seed_0.npy',
#  'embeddings_ep_50000_target_315_seed_0.png',
#  'action_hist_episode_50000_target_315_seed_0.npy',
#  'embeddings_ep_60000_target_315_seed_0.png',
#  'action_hist_episode_60000_target_315_seed_0.npy',
#  'embeddings_ep_70000_target_315_seed_0.png',
#  'action_hist_episode_70000_target_315_seed_0.npy',
#  'embeddings_ep_80000_target_315_seed_0.png',
#  'action_hist_episode_80000_target_315_seed_0.npy',
#  'embeddings_ep_90000_target_315_seed_0.png',
#  'action_hist_episode_90000_target_315_seed_0.npy',
#  'embeddings_ep_100000_target_315_seed_0.png',
#  'action_hist_episode_100000_target_315_seed_0.npy',
#  'embeddings_ep_110000_target_315_seed_0.png',
#  'action_hist_episode_110000_target_315_seed_0.npy',
#  'embeddings_ep_120000_target_315_seed_0.png',
#  'action_hist_episode_120000_target_315_seed_0.npy',
#  'embeddings_ep_130000_target_315_seed_0.png',
#  'action_hist_episode_130000_target_315_seed_0.npy',
#  'embeddings_ep_140000_target_315_seed_0.png',
#  'action_hist_episode_140000_target_315_seed_0.npy',
#  'embeddings_ep_150000_target_315_seed_0.png',
#  'action_hist_episode_150000_target_315_seed_0.npy',
#  'embeddings_ep_160000_target_315_seed_0.png',
#  'action_hist_episode_160000_target_315_seed_0.npy',
#  'embeddings_ep_170000_target_315_seed_0.png',
#  'action_hist_episode_170000_target_315_seed_0.npy',
#  'embeddings_ep_180000_target_315_seed_0.png',
#  'action_hist_episode_180000_target_315_seed_0.npy',
#  'embeddings_ep_190000_target_315_seed_0.png',
#  'action_hist_episode_190000_target_315_seed_0.npy',
#  'critic_loss_target_315_seed_0.npy',
#  'loss_target_315_seed_0.pdf',
#  'angle_differences_target_315_seed_0.npy',
#  'angular_error_target_315_seed_0.pdf',
#  'embeddings_ep_0_target_330_seed_0.png',
#  'action_hist_episode_0_target_330_seed_0.npy',
#  'action_hist_0_target_330_seed_0.pdf',
#  'embeddings_ep_10000_target_330_seed_0.png',
#  'action_hist_episode_10000_target_330_seed_0.npy',
#  'embeddings_ep_20000_target_330_seed_0.png',
#  'action_hist_episode_20000_target_330_seed_0.npy',
#  'embeddings_ep_30000_target_330_seed_0.png',
#  ...]

# %%
n_episodes = 100000
seed = 0 
example_target = 135
fp = Path(paper_fig_dir) / f'generalization_stats_seed_{seed}_target_{example_target}_rotation_-30.csv'
genstats = pd.read_csv(fp)

# %%
make_generalization_plot(genstats)
# Out:
# (<Figure size 150x160 with 1 Axes>, <Figure size 150x160 with 1 Axes>)

# %%
dfs = []
runlog_dfs = []
for seed in tqdm(range(10)): # change to 10 when done
    for target in tqdm(range(0, 360, 15), leave=False):
        fp = Path(paper_fig_dir) / f'generalization_stats_seed_{seed}_target_{target}_rotation_-30.csv'
        fp_runlog = Path(paper_fig_dir) / f'adaptation_run_log_seed_{seed}_target_{target}.csv'
        genstats = pd.read_csv(fp)
        runlog = pd.read_csv(fp_runlog)
        genstats['seed'] = seed
        genstats['target'] = target 
        runlog['seed'] = seed
        runlog['target'] = target
        runlog = runlog[runlog.episode< n_episodes]
        
        downsample_factor = 10000
        runlog['episode_bin'] = runlog.episode // downsample_factor
        runlog_ds = runlog.groupby('episode_bin').mean()
        dfs.append(genstats)
        runlog_dfs.append(runlog_ds)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
all_gen_data = pd.concat(dfs)
all_runlogs = pd.concat(runlog_dfs)

all_targets = all_gen_data.target.unique()

# %%
fig, axs = plt.subplots()
sns.lineplot(data=all_gen_data, x='angle from target', y='angular error',  errorbar='sd', ax=axs)
axs.set_ylabel('angular error')
axs.set_xlim([-90, 180])
axs.set_ylim([35, -15])
# Out:
# (35.0, -15.0)

# %%
fig, axs = plt.subplots()
sns.lineplot(data=all_gen_data, x='angle from target', y='rotation generalization',  errorbar='sd', ax=axs)
axs.set_ylabel('Rotation generalization')
axs.set_xlim([-90, 180])
# Out:
# (-90.0, 180.0)

# %% [markdown]
# ## plot the action histograms for pre- and post-adaptation

# %%
# first load pre-adapation model
example_reach_angle = 135
n_acts = 24

env_norot = ReachTask(pre_cfg)
act_hist_pre_dict = {}
for train_seed in range(10):
    model_weights_dir = paper_model_path
    model_weights_fn = f'fully_trained_policy_model_one_target_seed_{train_seed}_weight_decay_0.0001_tanh_policy_mean_target_{example_reach_angle}_n_actions_{n_acts}.pth'
    full_model_load_path = os.path.join(model_weights_dir, model_weights_fn)
    
    pre_agent = ACLearningAgentWithEmbedding(env_norot, pre_cfg,
                                             full_model_load_path=full_model_load_path,
                                             fg_load_path=None,
                                             g_plastic=False,
                                             f_plastic=False,
                                             actor_plastic=False,
                                             critic_plastic=False)
    
    
    act_hist_pre = []
    for i in range(10000):
        state_tensor = pre_agent.env.get_features(pre_agent.env.current_xy)
        action_ind, sample_emb, mean_emb, log_std_emb = pre_agent.select_action(state_tensor)
    
        act_hist_pre.append(action_ind)

    act_hist_pre_dict[train_seed] = act_hist_pre
# Out:
# initial loc: (10.0, 10.0), target:(np.float64(9.292893218813452), np.float64(10.707106781186548))

# %%
all_runlogs['episode'].max()
# Out:
# np.float64(94999.5)

# %%
def plot_action_distribution(action_history, ax=None, optimal_action_pre=None, optimal_action_post=None, **kwargs):
    # n_acts and colors are global params 
    
    bins = np.arange(0, n_acts + 1)
    n, bins, patches = ax.hist(action_history, bins=bins, density=True, **kwargs)
    
    for patch, color in zip(patches, colors):
        patch.set_facecolor(color)
    ax.set_xlabel('Action Index')
    ax.set_ylabel('Frequency')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    ax.set_xlabel('Action Index')
    ax.set_ylabel('Frequency')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    # Find optimal angles (pre and post rotation)
    if optimal_action_pre is not None:
        ax.axvline(x=optimal_action_pre + .5, color='black', linestyle='-', lw=1)
    if optimal_action_post is not None:
        ax.axvline(x=optimal_action_post + .5, color='black', linestyle='--', lw=1)

# %%
fig, axs = plt.subplots(figsize=(1.5, 1.5))

optimal_action_pre = pre_agent.find_optimal_action_ind(rotation_angle=0)
optimal_action_post = pre_agent.find_optimal_action_ind(rotation_angle=np.radians(-30))

mean_act_hist_pre = np.array(list(act_hist_pre_dict.values())).mean(axis=0)

plot_action_distribution(mean_act_hist_pre, ax=axs, optimal_action_pre=optimal_action_pre, optimal_action_post=optimal_action_post, alpha=1.)

# %%
# now for post-adaptation model 

act_hist_post_dict = {}
env_rot = ReachTask(post_cfg)

for train_seed in tqdm(range(10)):
    
    model_weights_dir = paper_model_path
    model_weights_fn = f'post_adaptation_model_seed_{train_seed}_rotation_-30_temp_2.5_weight_decay_0.0001_tanh_policy_mean_n_actions_24_target_{example_reach_angle}.0.pth'
    
    full_model_load_path = os.path.join(model_weights_dir, model_weights_fn)
    
    post_agent = ACLearningAgentWithEmbedding(env_rot, pre_cfg,
                                             full_model_load_path=full_model_load_path,
                                             fg_load_path=None,
                                             g_plastic=False,
                                             f_plastic=False,
                                             actor_plastic=False,
                                             critic_plastic=False)
    
    act_hist_post = []
    for i in tqdm(range(10000), leave=False):
        state_tensor = post_agent.env.get_features(post_agent.env.current_xy)
        action_ind, sample_emb, mean_emb, log_std_emb = post_agent.select_action(state_tensor)
    
        act_hist_post.append(action_ind)

    act_hist_post_dict[train_seed] = act_hist_post
# Out:
# initial loc: (10.0, 10.0), target:(np.float64(9.292893218813452), np.float64(10.707106781186548))
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(figsize=(1.5, 1.5))
mean_act_hist_post = np.array(list(act_hist_post_dict.values())).mean(axis=0)
plot_action_distribution(mean_act_hist_post, ax=ax, optimal_action_pre=optimal_action_pre, 
                             optimal_action_post=optimal_action_post, alpha=1.)

# %% [markdown]
# # plot action decoder outputs

# %%
from core.plotting import plot_f_output

# %%
example_train_seed = 6

# %%
model_weights_dir = paper_model_path
model_weights_fn = f'fully_trained_policy_model_one_target_seed_{example_train_seed}_weight_decay_0.0001_tanh_policy_mean_target_{example_reach_angle}_n_actions_{n_acts}.pth'
full_model_load_path = os.path.join(model_weights_dir, model_weights_fn)

pre_agent = ACLearningAgentWithEmbedding(env_norot, pre_cfg,
                                         full_model_load_path=full_model_load_path,
                                         fg_load_path=None,
                                         g_plastic=False,
                                         f_plastic=False,
                                         actor_plastic=False,
                                         critic_plastic=False)


act_hist_pre = []

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
pre_agent.plot_f_output(ax=ax, cbar=True, cmap=cmap)
ax.set_aspect('equal')

# %%
model_weights_dir = paper_model_path
model_weights_fn = f'post_adaptation_model_seed_{example_train_seed}_rotation_-30_temp_2.5_weight_decay_0.0001_tanh_policy_mean_n_actions_24_target_{example_reach_angle}.0.pth'

full_model_load_path = os.path.join(model_weights_dir, model_weights_fn)

post_agent = ACLearningAgentWithEmbedding(env_rot, pre_cfg,
                                         full_model_load_path=full_model_load_path,
                                         fg_load_path=None,
                                         g_plastic=False,
                                         f_plastic=False,
                                         actor_plastic=False,
                                         critic_plastic=False)

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
post_agent.plot_f_output(ax=ax, cbar=True, cmap=cmap)
ax.set_aspect('equal')

# %% [markdown]
# # plot krakauer et al data

# %%
sys.path.append('/diskone/amv125/action-embedding/data')
data_path = '/diskone/amv125/action-embedding/data/extracted_data_krakauer2000.csv'

def load_krakauer_data(data_path):
    df = pd.read_csv(data_path, header=None)
    df = df.rename({0: 'Target direction (°)', 1:'Percent adaptation', 2:'cat', 3: 'Participant'},axis=1)
    return df

krakauer_df = load_krakauer_data(data_path)

# %%
sns.lineplot(
    data=krakauer_df, 
    x='Target direction (°)', 
    y='Percent adaptation', 
    style='Participant',
    markers=['^', 'v', 'o', 's'],
    color=angle_diff_color,  
    dashes=False,
    markersize=10,
    legend=False
)
# Out:
# <Axes: xlabel='Target direction (°)', ylabel='Percent adaptation'>

# %% [markdown]
# # plot main figure

# %%
sample_emb
# Out:
# tensor([-0.7105,  0.6941], grad_fn=<TanhBackward0>)

# %%
save_dir = op.join(paper_fig_dir, 'fig4')
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
set_plotting_defaults(font_size=9)
fig = plt.figure(figsize=(11, 6))

# Simple gridspec without special accommodation for colorbar
gs_main = gridspec.GridSpec(2, 4, figure=fig, 
                           width_ratios=[2, 1, 1, 1],  # Equal widths
                           wspace=0.4, hspace=0.6)

# Create axes
axes = np.empty((2, 4), dtype=object)
axes[0, 0] = fig.add_subplot(gs_main[0, 0])
axes[0, 1] = fig.add_subplot(gs_main[0, 1])
axes[0, 2] = fig.add_subplot(gs_main[0, 2])
axes[0, 3] = fig.add_subplot(gs_main[0, 3])

# Create a sub-gridspec for the lower left position
gs_lower_left = gridspec.GridSpecFromSubplotSpec(1, 2, subplot_spec=gs_main[1, 0], 
                                                  wspace=.6, width_ratios=[1.5, 1])
# Left half of lower left
axes[1, 0] = fig.add_subplot(gs_lower_left[0, 0])

# Create another sub-gridspec for the right half of lower left (split into two rows)
gs_lower_left_right = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=gs_lower_left[0, 1],
                                                       hspace=0.3)
# Create two new axes for the split right column
ax_lower_left_bottom = fig.add_subplot(gs_lower_left_right[1, 0])
ax_lower_left_top = fig.add_subplot(gs_lower_left_right[0, 0], sharex=ax_lower_left_bottom)


# Continue with the rest of the main grid
axes[1, 1] = fig.add_subplot(gs_main[1, 1])
axes[1, 2] = fig.add_subplot(gs_main[1, 2])
axes[1, 3] = fig.add_subplot(gs_main[1, 3])

axes[0, 0].set_axis_off()

# plot krakauer data 
sns.lineplot(
    data=krakauer_df, 
    x='Target direction (°)', 
    y='Percent adaptation', 
    style='Participant',
    markers=['^', 'v', 'o', 's'],
    color=angle_diff_color,  
    dashes=False,
    markersize=6,
    legend=False,
    ax=axes[0,1]
)
axes[0, 1].spines['top'].set_visible(False)
axes[0, 1].spines['right'].set_visible(False)
# axes[0, 1].set_xlabel('angle from target (°)')
axes[0, 1].set_title('Data (Krakauer et al.)')

axes[0, 2].set_axis_off()


####################################################################################################################################
############################################ First row #############################################################################
####################################################################################################################################


# plot embedding loss across re-training 
sns.lineplot(data=all_runlogs[all_runlogs.target==example_target], x='episode', y='nll_loss', ax=axes[0,3],
            color=embedding_loss_color)
axes[0, 3].ticklabel_format(style='scientific', axis='x', scilimits=(4,4))
axes[0, 3].spines['top'].set_visible(False)
axes[0, 3].spines['right'].set_visible(False)
axes[0, 3].set_ylabel('Embedding loss')


####################################################################################################################################
############################################ Second row ############################################################################
####################################################################################################################################

# plot angular error across re-training
sns.lineplot(data=all_runlogs[all_runlogs.target==example_target], x='episode', y='angle_diff', ax=axes[1,0], color=angle_diff_color)
axes[1, 0].ticklabel_format(style='scientific', axis='x', scilimits=(4,4))
axes[1, 0].set_ylabel('Angular error (°)')
axes[1, 0].spines['top'].set_visible(False)
axes[1, 0].spines['right'].set_visible(False)


# plot action distributions pre and post adaptation 
bins = np.arange(0, pre_agent.env.n_actions + 1)
# Pre adaptation

plot_action_distribution(mean_act_hist_pre, ax=ax_lower_left_top, optimal_action_pre=optimal_action_pre, optimal_action_post=optimal_action_post)
ax_lower_left_top.tick_params(labelbottom=False, bottom=False)
ax_lower_left_top.set_xlabel('')


# Post adaptation
plot_action_distribution(mean_act_hist_post, ax=ax_lower_left_bottom, optimal_action_pre=optimal_action_pre, optimal_action_post=optimal_action_post)
ax_lower_left_bottom.set_ylabel('Frequency')
ax_lower_left_bottom.spines['right'].set_visible(False)
ax_lower_left_bottom.spines['top'].set_visible(False)

ax_lower_left_bottom.set_xlabel('Action Index')
ax_lower_left_bottom.set_ylim([0, 0.5])
ax_lower_left_bottom.set_yticks([0, 0.5])
ax_lower_left_top.set_ylim([0, 0.5])
ax_lower_left_top.set_yticks([0, 0.5])


# now the weight plots pre and post 
pre_agent.plot_f_output(ax=axes[1,1], cbar=True, cmap=cmap)
axes[1, 1].set_title('$f$ pre adaptation', fontsize=10)
post_agent.plot_f_output(ax=axes[1,2], cbar=True, cmap=cmap)
axes[1, 2].set_title('$f$ post adaptation', fontsize=10)


# plot generalization in terms of angular error
sns.lineplot(data=all_gen_data, x='angle from target', y='angular error',  errorbar='sd',
             ax=axes[1, 3], color=angle_diff_color)
axes[1, 3].set_ylabel('Negative angular error (°)')
axes[1, 3].set_xlabel('Target direction (°)')
axes[1, 3].set_xlim([-90, 180])
axes[1, 3].set_ylim([35, -15])
# multiply y ticks by -1 to make it negative angular error
yticks = axes[1, 3].get_yticks()
axes[1, 3].set_yticklabels([-1 * y for y in yticks])
axes[1, 3].spines['top'].set_visible(False)
axes[1, 3].spines['right'].set_visible(False)
axes[1, 3].set_title('Model')

plt.savefig(op.join(save_dir, 'fig4.svg'))
plt.savefig(op.join(save_dir, 'fig4.pdf'))
plt.savefig(op.join(save_dir, 'fig4.png'))
# Out:
# /tmp/ipykernel_3297325/2943514726.py:122: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1, 3].set_yticklabels([-1 * y for y in yticks])

# %% [markdown]
# # plot angular error generalization for all trained reach angles

# %%
set_plotting_defaults(font_size=10)
fig, axes = plt.subplots(4, 6, figsize=(9, 5), sharey='all', sharex='all')
axes = axes.flatten()

for i, target in enumerate(all_targets):
    sns.lineplot(data=all_gen_data, x='angle from target', y='angular error',  errorbar='sd',
                 ax=axes[i], color=angle_diff_color)
    axes[i].set_ylabel('angular error °')
    axes[i].set_xlabel('Angle from target °')
    axes[i].set_xlim([-90, 180])
    axes[i].set_ylim([35, -15])
    axes[i].set_title(f'target {all_targets[i]}°')

plt.tight_layout()
plt.savefig(paper_fig_dir / 'supp_angularerr_alltargets.pdf')

# %% [markdown]
# # plot rotation generalization measure (as in original experimental paper) for all trained reach angles

# %%
fig, axes = plt.subplots(4, 6, figsize=(9, 5), sharey='all', sharex='all')
axes = axes.flatten()
# todo: maybe nicer color for this
# todo: is this metric computed correctly? 
for i, target in enumerate(all_targets):
    sns.lineplot(data=all_gen_data, x='angle from target', y='rotation generalization',  errorbar='sd',
                 ax=axes[i], color='k')
    axes[i].set_ylabel('Rotation generalization')
    axes[i].set_xlim([-90, 180])
    axes[i].set_ylim([-10, 140])
    axes[i].set_title(f'target {all_targets[i]}')

plt.tight_layout()
plt.savefig(paper_fig_dir / 'rotation_generalization_alltargets.pdf')
