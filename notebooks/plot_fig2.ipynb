# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import matplotlib.pyplot as plt

from definitions import revision_fig_dir
from scripts.make_action_scaling_figure import (
    build_figure,
    load_single_joint_scaling_data,
    load_two_joint_scaling_data,
)
# %matplotlib inline

# %% [markdown]
# # Figure 2: action space scaling

# %% [markdown]
# Single- and two-joint reacher schematics with scaling results.
#
# - **Row 1**: A = single-joint reacher schematic; B = final success rate vs N (standard RL vs SL embedding)
# - **Row 2**: C = two-joint reacher schematic; D = final success rate vs N=k^2 (standard RL vs embedding)
#
# Panels B and D load real results via `load_single_joint_scaling_data()` / `load_two_joint_scaling_data()`. All plotting logic lives in scripts/make_action_scaling_figure.py; this notebook just calls it and previews/saves the output.

# %% [markdown]
# ## Inspect the underlying scaling data

# %%
two_joint_stats = load_two_joint_scaling_data()
two_joint_stats
# Out:
# {('standard', 64): (np.float64(0.9987499999999999),
#   np.float64(0.0006909634979907033)),
#  ('standard', 256): (np.float64(0.28125), np.float64(0.029269906568958424)),
#  ('standard', 576): (np.float64(0.19458333333333333),
#   np.float64(0.024104625823918344)),
#  ('standard', 1024): (np.float64(0.14791666666666667),
#   np.float64(0.00870773522666932)),
#  ('standard', 2304): (np.float64(0.10791666666666666),
#   np.float64(0.016076801350600394)),
#  ('embedding', 256): (np.float64(0.6183333333333333),
#   np.float64(0.024345601929985906)),
#  ('embedding', 576): (np.float64(0.62125), np.float64(0.008320302311548285)),
#  ('embedding', 64): (np.float64(0.9108333333333333),
#   np.float64(0.0012500000000000057)),
#  ('embedding', 1024): (np.float64(0.595), np.float64(0.03682729965664058)),
#  ('embedding', 2304): (np.float64(0.5912499999999999),
#   np.float64(0.032394995969885355)),
#  ('embedding', 4096): (np.float64(0.5475), np.float64(0.020021689627889933)),
# ...

# %% [markdown]
# ## Build and display figure 2

# %%
fig = build_figure()

# %% [markdown]
# ## Save figure 2

# %%
out = Path(revision_fig_dir) / "main_text_action_space_fig"
fig.savefig(str(out) + ".pdf", bbox_inches="tight")
fig.savefig(str(out) + ".png", dpi=300, bbox_inches="tight")
fig.savefig(str(out) + ".svg", bbox_inches="tight")
print("saved", out.name + ".pdf/.png/.svg")
# Out:
# saved main_text_action_space_fig.pdf/.png/.svg
